# %%
import plumed
import numpy as np
import pandas as pd
import MDAnalysis as mda
import nglview
import os
from pathlib import Path
from psfgen import PsfGen
import subprocess
import gromacs
import panedr
from gromacs.setup import *

import matplotlib.pyplot as plt

import yaml
# Out:
# [dgx-master:2254566] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 237
# [dgx-master:2254566] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 246

# %%
base  = Path(os.getcwd()).parent

# %%
base / 'src'
# Out:
# PosixPath('/rg/mendels_prj/zadoki/chignolin_test/src')

# %%
import sys
extra_path = str(base / 'src' )

# %%
if extra_path not in sys.path:
    sys.path.append(extra_path)
    
from utils import clean, run_omp_slurm, run_mpi_slurm

# %%
# set some general constants
NSTEPS = 1000000
NSTXOUT = 100
TEMPERATURE = 340
NSTENERGY=100

# %% [markdown]
# ## Simulate the starting position for chignolin

# %% [markdown]
# ## Folded state

# %%
# create pdb psf files

gen = PsfGen(output="/dev/null")  # Suppress output since there's too much
#gen.read_topology('../data/top_all27_prot_lipid_na.inp')
gen.read_topology(str(base / 'data/top_all27_prot_lipid_na.inp'))

# %%
# YYDPETGTWY -> YYDPENGTWY 
# Mutate 5TTR -> 5ASN
gen.alias_atom(resname='ILE' , top_atomname='CD', pdb_atomname='CD1')
gen.add_segment(segid="P",
                pdbfile=str(base / 'data/YYDPETGTWY.pdb'),
                first='NTER',
                last='CTER',
                mutate=[('5','ASN')]
                )
gen.read_coords(segid="P", filename=str(base / 'data/YYDPETGTWY.pdb'))
gen.regenerate_resids()
gen.regenerate_angles()
gen.regenerate_dihedrals()
gen.guess_coords()

# %%
# make folder
fdir = base / 'data/interim/YYDPENGTWY/state_folded'
os.makedirs(str(fdir), exist_ok=True)
gen.write_pdb(str(fdir / 'YYDPENGTWY.pdb'))
gen.write_psf(str(fdir / 'YYDPENGTWY.psf'))

# %%
# solvate and ionize 
os.chdir(fdir)

# %%
# original topology ff 
f1 = topology(protein='protein_solvate', struct='YYDPENGTWY.pdb',  ff='charmm27', water='tip3p', ignh=True, posrefc=50)
# solvate and ionize
f2 = solvate(boxtype='cubic',distance=1.0, water='tip3p', **f1)
# Out:
#                :-) GROMACS - gmx pdb2gmx, 2020.6-plumed-2.8.0 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx pdb2gmx, version 2020.6-plumed-2.8.0
# Executable:   /home/zadoki/miniconda3/envs/bpti/bin/gmx_mpi
# Data prefix:  /home/zadoki/miniconda3/envs/bpti
# Working dir:  /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/top
# Command line:
#   gmx_mpi pdb2gmx -ignh -posrefc 50 -f /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/YYDPENGTWY.pdb -o protein_solvate.pdb -p system.top -i posres.itp -ff charmm27 -water tip3p
#
# Opening force field file /home/zadoki/miniconda3/envs/bpti/share/gromacs/top/charmm27.ff/aminoacids.r2b
# Opening force field file /home/zadoki/miniconda3/envs/bpti/share/gromacs/top/charmm27.ff/rna.r2b
#
# WARNING: there were 5 atoms with zero occupancy and 0 atoms with
#          occupancy unequal to one (out of 94 atoms). Check your pdb file.
#
# Opening force field file /home/zadoki/miniconda3/envs/bpti/share/gromacs/top/charmm27.ff/atomtypes.atp
# Opening force field file /home/zadoki/miniconda3/envs/bpti/share/gromacs/top/charmm27.ff/aminoacids.rtp
# Opening force field file /home/zadoki/miniconda3/envs/bpti/share/gromacs/top/charmm27.ff/dna.rtp
# Opening force field file /home/zadoki/miniconda3/envs/bpti/share/gromacs/top/charmm27.ff/lipids.rtp
# Opening force field file /home/zadoki/miniconda3/envs/bpti/share/gromacs/top/charmm27.ff/rna.rtp
# Opening force field file /home/zadoki/miniconda3/envs/bpti/share/gromacs/top/charmm27.ff/aminoacids.hdb
# Opening force field file /home/zadoki/miniconda3/envs/bpti/share/gromacs/top/charmm27.ff/dna.hdb
# Opening force field file /home/zadoki/miniconda3/envs/bpti/share/gromacs/top/charmm27.ff/lipids.hdb
# Opening force field file /home/zadoki/miniconda3/envs/bpti/share/gromacs/top/charmm27.ff/rna.hdb
# Opening force field file /home/zadoki/miniconda3/envs/bpti/share/gromacs/top/charmm27.ff/aminoacids.n.tdb
# Opening force field file /home/zadoki/miniconda3/envs/bpti/share/gromacs/top/charmm27.ff/dna.n.tdb
# Opening force field file /home/zadoki/miniconda3/envs/bpti/share/gromacs/top/charmm27.ff/rna.n.tdb
# Opening force field file /home/zadoki/miniconda3/envs/bpti/share/gromacs/top/charmm27.ff/aminoacids.c.tdb
# Opening force field file /home/zadoki/miniconda3/envs/bpti/share/gromacs/top/charmm27.ff/dna.c.tdb
# Opening force field file /home/zadoki/miniconda3/envs/bpti/share/gromacs/top/charmm27.ff/rna.c.tdb
# 8 out of 8 lines of specbond.dat converted successfully
# Opening force field file /home/zadoki/miniconda3/envs/bpti/share/gromacs/top/charmm27.ff/aminoacids.arn
# Opening force field file /home/zadoki/miniconda3/envs/bpti/share/gromacs/top/charmm27.ff/dna.arn
# Opening force field file /home/zadoki/miniconda3/envs/bpti/share/gromacs/top/charmm27.ff/rna.arn
# Making bonds...
# Number of bonds was 171, now 171
# Generating angles, dihedrals and pairs...
# Before cleaning: 439 pairs
# Before cleaning: 449 dihedrals
# Keeping all generated dihedrals
# Making cmap torsions...
# There are    8 cmap torsion pairs
# There are  449 dihedrals,   25 impropers,  298 angles
#            427 pairs,      171 bonds and     0 virtual sites
# Total mass 1305.323 a.m.u.
# Total charge -2.000 e
# Writing topology
#
# Writing coordinate file...
#
# GROMACS reminds you: "My Ass May Be Dumb, But I Ain't No Dumbass." (Jackie Brown)
#
# [dgx-master:2302512] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 237
# [dgx-master:2302512] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 246
# Using the Charmm27 force field in directory charmm27.ff
#
# going to rename charmm27.ff/aminoacids.r2b
# going to rename charmm27.ff/rna.r2b
# Reading /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/YYDPENGTWY.pdb...
# Read '', 94 atoms
# Analyzing pdb file
# Splitting chemical chains based on TER records or chain id changing.
# There are 1 chains and 0 blocks of water and 10 residues with 94 atoms
#
#   chain  #res #atoms
#   1 'A'    10     94
#
# Reading residue database... (Charmm27)
# Processing chain 1 'A' (94 atoms, 10 residues)
# Identified residue TYR0 as a starting terminus.
# Identified residue TYR9 as a ending terminus.
# Start terminus TYR-0: NH3+
# End terminus TYR-9: COO-
# Checking for duplicate atoms....
# Generating any missing hydrogen atoms and/or adding termini.
# Now there are 10 residues with 166 atoms
# 		--------- PLEASE NOTE ------------
# You have successfully generated a topology from: /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/YYDPENGTWY.pdb.
# The Charmm27 force field and the tip3p water model are used.
# 		--------- ETON ESAELP ------------
#               :-) GROMACS - gmx editconf, 2020.6-plumed-2.8.0 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx editconf, version 2020.6-plumed-2.8.0
# Executable:   /home/zadoki/miniconda3/envs/bpti/bin/gmx_mpi
# Data prefix:  /home/zadoki/miniconda3/envs/bpti
# Working dir:  /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/solvate
# Command line:
#   gmx_mpi editconf -f /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/top/protein_solvate.pdb -o boxed.gro -bt cubic -d 1.0
#
#
# GROMACS reminds you: "My Ass May Be Dumb, But I Ain't No Dumbass." (Jackie Brown)
#
# [dgx-master:2302584] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 237
# [dgx-master:2302584] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 237
# [dgx-master:2302584] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 246
# Note that major changes are planned in future for editconf, to improve usability and utility.
# Read 166 atoms
# No velocities found
#     system size :  1.619  1.509  1.306 (nm)
#     diameter    :  1.784               (nm)
#     center      :  0.017 -0.501 -0.632 (nm)
#     box vectors :  0.000  0.000  0.000 (nm)
#     box angles  :   0.00   0.00   0.00 (degrees)
#     box volume  :   0.00               (nm^3)
#     shift       :  1.875  2.393  2.524 (nm)
# new center      :  1.892  1.892  1.892 (nm)
# new box vectors :  3.784  3.784  3.784 (nm)
# new box angles  :  90.00  90.00  90.00 (degrees)
# new box volume  :  54.18               (nm^3)
#
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary.
#
# NOTE: From version 5.0 gmx solvate uses the Van der Waals radii
# from the source below. This means the results may be different
# compared to previous GROMACS versions.
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# A. Bondi
# van der Waals Volumes and Radii
# J. Phys. Chem. 68 (1964) pp. 441-451
# -------- -------- --- Thank You --- -------- --------
#                :-) GROMACS - gmx solvate, 2020.6-plumed-2.8.0 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx solvate, version 2020.6-plumed-2.8.0
# Executable:   /home/zadoki/miniconda3/envs/bpti/bin/gmx_mpi
# Data prefix:  /home/zadoki/miniconda3/envs/bpti
# Working dir:  /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/solvate
# Command line:
#   gmx_mpi solvate -p /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/top/system.top -cp boxed.gro -cs spc216 -o solvated.gro
#
# Reading solute configuration
# Reading solvent configuration
#
# Initialising inter-atomic distances...
# Generating solvent configuration
# Will generate new solvent configuration of 3x3x3 boxes
# Solvent box contains 6921 atoms in 2307 residues
# Removed 1815 solvent atoms due to solvent-solvent overlap
# Removed 171 solvent atoms due to solute-solvent overlap
# Sorting configuration
# Found 1 molecule type:
#     SOL (   3 atoms):  1645 residues
# Generated solvent containing 4935 atoms in 1645 residues
# Writing generated configuration to solvated.gro
#
# Output configuration contains 5101 atoms in 1655 residues
# Volume                 :     54.1753 (nm^3)
# Density                :       950.5 (g/l)
# Number of solvent molecules:   1645
#
# Processing topology
#
# Back Off! I just backed up /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/top/system.top to /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/top/#system.top.1#
#
# GROMACS reminds you: "My Ass May Be Dumb, But I Ain't No Dumbass." (Jackie Brown)
#
# [dgx-master:2302632] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 237
# [dgx-master:2302632] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 237
# [dgx-master:2302632] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 246
# Adding line for 1645 solvent molecules with resname (SOL) to topology file (/rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/top/system.top)
#                :-) GROMACS - gmx genion, 2020.6-plumed-2.8.0 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx genion, version 2020.6-plumed-2.8.0
# Executable:   /home/zadoki/miniconda3/envs/bpti/bin/gmx_mpi
# Data prefix:  /home/zadoki/miniconda3/envs/bpti
# Working dir:  /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/solvate
# Command line:
#   gmx_mpi genion -s topol.tpr -o ionized.gro -p /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/top/system.top -pname NA -nname CL -np 2 -nn 0
#
# Reading file topol.tpr, VERSION 2020.6-plumed-2.8.0 (single precision)
# Reading file topol.tpr, VERSION 2020.6-plumed-2.8.0 (single precision)
# Group     0 (         System) has  5101 elements
# Group     1 (        Protein) has   166 elements
# Group     2 (      Protein-H) has    94 elements
# Group     3 (        C-alpha) has    10 elements
# Group     4 (       Backbone) has    30 elements
# Group     5 (      MainChain) has    39 elements
# Group     6 (   MainChain+Cb) has    48 elements
# Group     7 (    MainChain+H) has    50 elements
# Group     8 (      SideChain) has   116 elements
# Group     9 (    SideChain-H) has    55 elements
# Group    10 (    Prot-Masses) has   166 elements
# Group    11 (    non-Protein) has  4935 elements
# Group    12 (          Water) has  4935 elements
# Group    13 (            SOL) has  4935 elements
# Group    14 (      non-Water) has   166 elements
# Select a group: Number of (3-atomic) solvent molecules: 1645
#
# Back Off! I just backed up /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/top/system.top to /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/top/#system.top.2#
# Using random seed -21386277.
# Replacing solvent molecule 1517 (atom 4717) with NA
# Replacing solvent molecule 812 (atom 2602) with NA
#
#
# GROMACS reminds you: "The way to succeed is to double your failure rate." (Thomas J. Watson)
#
# [dgx-master:2302789] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 237
# [dgx-master:2302789] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 246
# Will try to add 2 NA ions and 0 CL ions.
# Select a continuous group of solvent molecules
# Selected 13: 'SOL'
#
# Processing topology
# Replacing 2 solute molecules in topology file (/rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/top/system.top)  by 2 NA and 0 CL ions.
#               :-) GROMACS - gmx make_ndx, 2020.6-plumed-2.8.0 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx make_ndx, version 2020.6-plumed-2.8.0
# Executable:   /home/zadoki/miniconda3/envs/bpti/bin/gmx_mpi
# Data prefix:  /home/zadoki/miniconda3/envs/bpti
# Working dir:  /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/solvate
# Command line:
#   gmx_mpi make_ndx -f ionized.tpr -o main.ndx
#
#
# Reading structure file
# Reading file ionized.tpr, VERSION 2020.6-plumed-2.8.0 (single precision)
# Reading file ionized.tpr, VERSION 2020.6-plumed-2.8.0 (single precision)
#
# GROMACS reminds you: "Don't Push Me, Cause I'm Close to the Edge" (Tricky)
#
# [dgx-master:2302936] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 237
# [dgx-master:2302936] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 237
# [dgx-master:2302936] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 246
#               :-) GROMACS - gmx make_ndx, 2020.6-plumed-2.8.0 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx make_ndx, version 2020.6-plumed-2.8.0
# Executable:   /home/zadoki/miniconda3/envs/bpti/bin/gmx_mpi
# Data prefix:  /home/zadoki/miniconda3/envs/bpti
# Working dir:  /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/solvate
# Command line:
#   gmx_mpi make_ndx -f ionized.tpr -n main.ndx -o main.ndx
#
#
# Reading structure file
# Reading file ionized.tpr, VERSION 2020.6-plumed-2.8.0 (single precision)
# Reading file ionized.tpr, VERSION 2020.6-plumed-2.8.0 (single precision)
#
# Back Off! I just backed up main.ndx to ./#main.ndx.1#
#
# GROMACS reminds you: "Don't Push Me, Cause I'm Close to the Edge" (Tricky)
#
# [dgx-master:2303006] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 237
# [dgx-master:2303006] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 237
# [dgx-master:2303006] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 237
# [dgx-master:2303006] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 246
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Select group for centering
# Selected 18: '__main__'
# Select group for output
# Selected 0: 'System'
#                :-) GROMACS - gmx trjconv, 2020.6-plumed-2.8.0 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx trjconv, version 2020.6-plumed-2.8.0
# Executable:   /home/zadoki/miniconda3/envs/bpti/bin/gmx_mpi
# Data prefix:  /home/zadoki/miniconda3/envs/bpti
# Working dir:  /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/solvate
# Command line:
#   gmx_mpi trjconv -ur compact -center -boxcenter tric -pbc mol -f ionized.gro -s ionized.tpr -o compact.pdb -n main.ndx
#
# Will write pdb: Protein data bank file
# Reading file ionized.tpr, VERSION 2020.6-plumed-2.8.0 (single precision)
# Reading file ionized.tpr, VERSION 2020.6-plumed-2.8.0 (single precision)
# Group     0 (         System) has  5097 elements
# Group     1 (        Protein) has   166 elements
# Group     2 (      Protein-H) has    94 elements
# Group     3 (        C-alpha) has    10 elements
# Group     4 (       Backbone) has    30 elements
# Group     5 (      MainChain) has    39 elements
# Group     6 (   MainChain+Cb) has    48 elements
# Group     7 (    MainChain+H) has    50 elements
# Group     8 (      SideChain) has   116 elements
# Group     9 (    SideChain-H) has    55 elements
# Group    10 (    Prot-Masses) has   166 elements
# Group    11 (    non-Protein) has  4931 elements
# Group    12 (          Water) has  4929 elements
# Group    13 (            SOL) has  4929 elements
# Group    14 (      non-Water) has   168 elements
# Group    15 (            Ion) has     2 elements
# Group    16 (             NA) has     2 elements
# Group    17 ( Water_and_ions) has  4931 elements
# Group    18 (       __main__) has   166 elements
# Group    19 (__environment__) has  4931 elements
# Select a group: Group     0 (         System) has  5097 elements
# Group     1 (        Protein) has   166 elements
# Group     2 (      Protein-H) has    94 elements
# Group     3 (        C-alpha) has    10 elements
# Group     4 (       Backbone) has    30 elements
# Group     5 (      MainChain) has    39 elements
# Group     6 (   MainChain+Cb) has    48 elements
# Group     7 (    MainChain+H) has    50 elements
# Group     8 (      SideChain) has   116 elements
# Group     9 (    SideChain-H) has    55 elements
# Group    10 (    Prot-Masses) has   166 elements
# Group    11 (    non-Protein) has  4931 elements
# Group    12 (          Water) has  4929 elements
# Group    13 (            SOL) has  4929 elements
# Group    14 (      non-Water) has   168 elements
# Group    15 (            Ion) has     2 elements
# Group    16 (             NA) has     2 elements
# Group    17 ( Water_and_ions) has  4931 elements
# Group    18 (       __main__) has   166 elements
# Group    19 (__environment__) has  4931 elements
# Select a group: Reading frames from gro file 'Protein in water', 5097 atoms.
# Reading frame       0 time    0.000
# Precision of ionized.gro is 0.001 (nm)
# Last frame          0 time    0.000
#
#
# GROMACS reminds you: "Don't Push Me, Cause I'm Close to the Edge" (Tricky)
#
# [dgx-master:2303083] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 237
# [dgx-master:2303083] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 246

# %%
# minimize rigid
f3 = energy_minimize(integrator='steep',maxwarn=10, **f2)
# Out:
# /home/zadoki/miniconda3/envs/gromacs_plumed/lib/python3.9/site-packages/gromacs/setup.py:781: UsageWarning: Unprocessed mdp option are interpreted as options for grompp:
# {'maxwarn': 10, 'pp': 'processed.top'}
#   warnings.warn(wmsg, category=UsageWarning)
#                :-) GROMACS - gmx grompp, 2020.6-plumed-2.8.0 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx grompp, version 2020.6-plumed-2.8.0
# Executable:   /home/zadoki/miniconda3/envs/bpti/bin/gmx_mpi
# Data prefix:  /home/zadoki/miniconda3/envs/bpti
# Working dir:  /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/em
# Command line:
#   gmx_mpi grompp -f em.mdp -o em.tpr -c /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/solvate/ionized.gro -r /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/solvate/ionized.gro -p /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/top/system.top -maxwarn 10 -pp processed.top
#
# Ignoring obsolete mdp entry 'cpp'
# Ignoring obsolete mdp entry 'optimize_fft'
# Ignoring obsolete mdp entry 'ns_type'
#
# NOTE 1 [file em.mdp]:
#   Replacing vdwtype=Shift by the equivalent combination of vdwtype=Cut-off
#   and vdw_modifier=Force-switch
#
#
# NOTE 2 [file em.mdp]:
#   nstcomm < nstcalcenergy defeats the purpose of nstcalcenergy, setting
#   nstcomm to nstcalcenergy
#
# Setting the LD random seed to -20186118
# Generated 20503 of the 20503 non-bonded parameter combinations
# Generating 1-4 interactions: fudge = 1
# Generated 17396 of the 20503 1-4 parameter combinations
# Excluding 3 bonded neighbours molecule type 'Protein_chain_A'
# Excluding 2 bonded neighbours molecule type 'SOL'
# Excluding 1 bonded neighbours molecule type 'NA'
#
# WARNING 1 [file system.top, line 1628]:
#   The following macros were defined in the 'define' mdp field with the -D
#   prefix, but were not used in the topology:
#       FLEXSPC
#   If you haven't made a spelling error, either use the macro you defined,
#   or don't define the macro
#
# Number of degrees of freedom in T-Coupling group rest is 10359.00
#
# NOTE 3 [file em.mdp]:
#   Removing center of mass motion in the presence of position restraints
#   might cause artifacts. When you are using position restraints to
#   equilibrate a macro-molecule, the artifacts are usually negligible.
#
# Estimate for the relative computational load of the PME mesh part: 0.17
#
# There were 3 notes
#
# There was 1 warning
#
# GROMACS reminds you: "Sacrifices must be made" (Otto Lilienthal, dying after having crashed with his glider in 1896)
#
# /home/zadoki/miniconda3/envs/gromacs_plumed/lib/python3.9/site-packages/gromacs/run.py:445: AutoCorrectionWarning: No 'mdrun_d' binary found so trying 'mdrun' instead.
# (Note that energy minimization runs better with mdrun_d.)
#   warnings.warn(wmsg, category=AutoCorrectionWarning)
# [dgx-master:2310087] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 237
# [dgx-master:2310087] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 246
# Analysing residue names:
# There are:    10    Protein residues
# There are:  1643      Water residues
# There are:     2        Ion residues
# Analysing Protein...
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 32x32x32, spacing 0.118 0.118 0.118
# This run will generate roughly 0 Mb of data
#                 :-) GROMACS - gmx mdrun, 2020.6-plumed-2.8.0 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx mdrun, version 2020.6-plumed-2.8.0
# Executable:   /home/zadoki/miniconda3/envs/bpti/bin/gmx_mpi
# Data prefix:  /home/zadoki/miniconda3/envs/bpti
# Working dir:  /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/em
# Command line:
#   gmx_mpi mdrun -v -stepout 10 -deffnm em -c em.pdb
#
# Compiled SIMD: SSE2, but for this host/run AVX_512 might be better (see log).
# The current CPU can measure timings more accurately than the code in
# gmx mdrun was configured to use. This might affect your simulation
# speed as accurate timings are needed for load-balancing.
# Please consider rebuilding gmx mdrun with the GMX_USE_RDTSCP=ON CMake option.
# Reading file em.tpr, VERSION 2020.6-plumed-2.8.0 (single precision)
#
# Using 1 MPI process
# Using 16 OpenMP threads
#
#
# Steepest Descents:
#    Tolerance (Fmax)   =  5.00000e+02
#    Number of steps    =         1000
# Step=    0, Dmax= 1.0e-02 nm, Epot= -5.94931e+04 Fmax= 3.99261e+04, atom= 2378
# Step=    1, Dmax= 1.0e-02 nm, Epot= -6.15249e+04 Fmax= 1.95565e+04, atom= 2378
# Step=    2, Dmax= 1.2e-02 nm, Epot= -6.31402e+04 Fmax= 9.49020e+03, atom= 2378
# Step=    3, Dmax= 1.4e-02 nm, Epot= -6.45969e+04 Fmax= 4.68484e+03, atom= 2378
# Step=    4, Dmax= 1.7e-02 nm, Epot= -6.61916e+04 Fmax= 5.35014e+03, atom= 164
# Step=    5, Dmax= 2.1e-02 nm, Epot= -6.67753e+04 Fmax= 1.30064e+04, atom= 164
# Step=    6, Dmax= 2.5e-02 nm, Epot= -6.70240e+04 Fmax= 1.33604e+04, atom= 84
# Step=    8, Dmax= 1.5e-02 nm, Epot= -6.78063e+04 Fmax= 6.92134e+03, atom= 84
#
# writing lowest energy coordinates.
#
# Steepest Descents converged to Fmax < 500 in 189 steps
# Potential Energy  = -7.6573375e+04
# Maximum force     =  4.9429291e+02 on atom 133
# Norm of force     =  4.1375676e+01
#
# GROMACS reminds you: "Problems worthy of attack prove their worth by hitting back." (Piet Hein)
#
# [dgx-master:2310166] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 237
# [dgx-master:2310166] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 246

# %%
# restrained md npt 20ns
MD_restrained(r=str(fdir / 'em/em.pdb') , maxwarn=10, nstxout=NSTXOUT, nstvout=0, nstenergy=NSTENERGY, nstxtcout = 0, nsteps= 100000, **f3)
# Out:
#               :-) GROMACS - gmx make_ndx, 2020.6-plumed-2.8.0 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx make_ndx, version 2020.6-plumed-2.8.0
# Executable:   /home/zadoki/miniconda3/envs/bpti/bin/gmx_mpi
# Data prefix:  /home/zadoki/miniconda3/envs/bpti
# Working dir:  /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/MD_POSRES
# Command line:
#   gmx_mpi make_ndx -f /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/em/em.pdb -o md.ndx
#
#
# Reading structure file
#
# GROMACS reminds you: "Shake Yourself" (YES)
#
# [dgx-master:2312557] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 237
# [dgx-master:2312557] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 246
#               :-) GROMACS - gmx make_ndx, 2020.6-plumed-2.8.0 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx make_ndx, version 2020.6-plumed-2.8.0
# Executable:   /home/zadoki/miniconda3/envs/bpti/bin/gmx_mpi
# Data prefix:  /home/zadoki/miniconda3/envs/bpti
# Working dir:  /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/MD_POSRES
# Command line:
#   gmx_mpi make_ndx -f /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/em/em.pdb -n md.ndx -o md.ndx
#
#
# Reading structure file
#
# Back Off! I just backed up md.ndx to ./#md.ndx.1#
#
# GROMACS reminds you: "Come and play on the hospital roof, I got something that's yours" (Sherlock)
#
# [dgx-master:2312620] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 237
# [dgx-master:2312620] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 246
# /home/zadoki/miniconda3/envs/gromacs_plumed/lib/python3.9/site-packages/gromacs/setup.py:1116: AutoCorrectionWarning: Size of __main__ is only 3.4% of __environment__ so we use 'System' for T-coupling and ref_t = 300 K and tau_t = 0.1 1/ps (can be changed in mdp_parameters).
#
#   warnings.warn(wmsg, category=AutoCorrectionWarning)
# /home/zadoki/miniconda3/envs/gromacs_plumed/lib/python3.9/site-packages/gromacs/setup.py:781: UsageWarning: Unprocessed mdp option are interpreted as options for grompp:
# {'pp': 'processed.top', 'r': '/rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/em/em.pdb', 'maxwarn': 10}
#   warnings.warn(wmsg, category=UsageWarning)
#                :-) GROMACS - gmx grompp, 2020.6-plumed-2.8.0 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx grompp, version 2020.6-plumed-2.8.0
# Executable:   /home/zadoki/miniconda3/envs/bpti/bin/gmx_mpi
# Data prefix:  /home/zadoki/miniconda3/envs/bpti
# Working dir:  /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/MD_POSRES
# Command line:
#   gmx_mpi grompp -f md.mdp -p /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/top/system.top -c /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/em/em.pdb -n /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/MD_POSRES/md.ndx -o md.tpr -pp processed.top -r /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/em/em.pdb -maxwarn 10
#
# Ignoring obsolete mdp entry 'andersen_seed'
# Ignoring obsolete mdp entry 'optimize_fft'
# Ignoring obsolete mdp entry 'ns_type'
# Replacing old mdp entry 'nstxtcout' by 'nstxout-compressed'
# Replacing old mdp entry 'xtc-precision' by 'compressed-x-precision'
#
# NOTE 1 [file md.mdp]:
#   With Verlet lists the optimal nstlist is >= 10, with GPUs >= 20. Note
#   that with the Verlet scheme, nstlist has no effect on the accuracy of
#   your simulation.
#
# Setting the LD random seed to -872517133
# Generated 20503 of the 20503 non-bonded parameter combinations
# Generating 1-4 interactions: fudge = 1
# Generated 17396 of the 20503 1-4 parameter combinations
# Excluding 3 bonded neighbours molecule type 'Protein_chain_A'
# Excluding 2 bonded neighbours molecule type 'SOL'
# Excluding 1 bonded neighbours molecule type 'NA'
# Velocities were taken from a Maxwell distribution at 300 K
# The center of mass of the position restraint coord's is  1.885  1.910  1.890
# The center of mass of the position restraint coord's is  1.885  1.910  1.890
# Number of degrees of freedom in T-Coupling group System is 10287.00
#
# NOTE 2 [file md.mdp]:
#   Removing center of mass motion in the presence of position restraints
#   might cause artifacts. When you are using position restraints to
#   equilibrate a macro-molecule, the artifacts are usually negligible.
#
# Estimate for the relative computational load of the PME mesh part: 0.19
#
# There were 2 notes
#
# GROMACS reminds you: "Come and play on the hospital roof, I got something that's yours" (Sherlock)
# turning H bonds into constraints...
# turning H bonds into constraints...
# turning H bonds into constraints...
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 300 K
# Calculated rlist for 1x1 atom pair-list as 1.008 nm, buffer size 0.008 nm
# Set rlist, assuming 4x4 atom pair-list, to 1.000 nm, buffer size 0.000 nm
# Note that mdrun will redetermine rlist based on the actual pair-list setup
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 32x32x32, spacing 0.118 0.118 0.118
# This run will generate roughly 60 Mb of data
# [dgx-master:2312672] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 237
# [dgx-master:2312672] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 237
# [dgx-master:2312672] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 246
# {'struct': '/rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/MD_POSRES/md.gro',
#  'top': '/rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/top/system.top',
#  'ndx': '/rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/MD_POSRES/md.ndx',
#  'qscript': ['./local.sh'],
#  'mainselection': '"Protein"',
#  'deffnm': 'md',
#  'r': '/rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/em/em.pdb',
#  'maxwarn': 10,
#  'nstxout': 100,
#  'nstvout': 0,
#  'nstenergy': 100,
#  'nstxtcout': 0,
#  'nsteps': 100000,
#  'nstfout': '0',
#  'nstlog': '500'}

# %%
os.chdir(fdir / 'MD_POSRES')

# %%
subprocess.run('gmx_mpi mdrun  -v -deffnm md  -ntomp 8 ', shell=True )
# Out:
#                 :-) GROMACS - gmx mdrun, 2020.6-plumed-2.8.0 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx mdrun, version 2020.6-plumed-2.8.0
# Executable:   /home/zadoki/miniconda3/envs/bpti/bin/gmx_mpi
# Data prefix:  /home/zadoki/miniconda3/envs/bpti
# Working dir:  /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/MD_POSRES
# Command line:
#   gmx_mpi mdrun -v -deffnm md -ntomp 8
#
# Compiled SIMD: SSE2, but for this host/run AVX_512 might be better (see log).
# The current CPU can measure timings more accurately than the code in
# gmx mdrun was configured to use. This might affect your simulation
# speed as accurate timings are needed for load-balancing.
# Please consider rebuilding gmx mdrun with the GMX_USE_RDTSCP=ON CMake option.
# Reading file md.tpr, VERSION 2020.6-plumed-2.8.0 (single precision)
# Changing nstlist from 5 to 50, rlist from 1 to 1.106
#
#
# Using 1 MPI process
# Using 8 OpenMP threads
#
#
# NOTE: The number of threads is not equal to the number of (logical) cores
#       and the -pin option is set to auto: will not pin threads to cores.
#       This can lead to significant performance degradation.
#       Consider using -pin on (and -pinoffset in case you run multiple jobs).
# starting mdrun 'Protein in water'
# 100000 steps,    200.0 ps.
# step 99900, remaining wall clock time:     0 s
# Writing final coordinates.
# step 100000, remaining wall clock time:     0 s
#                Core t (s)   Wall t (s)        (%)
#        Time:     2779.008      347.379      800.0
#                  (ns/day)    (hour/ns)
# Performance:       49.744        0.482
#
# GROMACS reminds you: "Academe, n.: An ancient school where morality and philosophy were taught. Academy, n.: A modern school where football is taught." (Ambrose Bierce)
# CompletedProcess(args='gmx_mpi mdrun  -v -deffnm md  -ntomp 8 ', returncode=0)
# [dgx-master:2316977] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 237
# [dgx-master:2316977] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 237
# [dgx-master:2316977] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 246

# %%
os.chdir(fdir)

# %%
MD(r=str(fdir / 'MD_POSRES/md.tpr') , maxwarn=10, nstxout=NSTXOUT, nstvout=0, nstenergy=NSTENERGY, nstxtcout = 0, nsteps= NSTEPS, **f3)
# Out:
#               :-) GROMACS - gmx make_ndx, 2020.6-plumed-2.8.0 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx make_ndx, version 2020.6-plumed-2.8.0
# Executable:   /home/zadoki/miniconda3/envs/bpti/bin/gmx_mpi
# Data prefix:  /home/zadoki/miniconda3/envs/bpti
# Working dir:  /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/MD
# Command line:
#   gmx_mpi make_ndx -f /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/em/em.pdb -o md.ndx
#
#
# Reading structure file
#
# GROMACS reminds you: "You're About to Hurt Somebody" (Jazzy Jeff)
#
# [dgx-master:2327726] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 237
# [dgx-master:2327726] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 237
# [dgx-master:2327726] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 237
# [dgx-master:2327726] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 246
#               :-) GROMACS - gmx make_ndx, 2020.6-plumed-2.8.0 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx make_ndx, version 2020.6-plumed-2.8.0
# Executable:   /home/zadoki/miniconda3/envs/bpti/bin/gmx_mpi
# Data prefix:  /home/zadoki/miniconda3/envs/bpti
# Working dir:  /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/MD
# Command line:
#   gmx_mpi make_ndx -f /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/em/em.pdb -n md.ndx -o md.ndx
#
#
# Reading structure file
#
# Back Off! I just backed up md.ndx to ./#md.ndx.1#
#
# GROMACS reminds you: "You're About to Hurt Somebody" (Jazzy Jeff)
#
# [dgx-master:2327754] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 237
# [dgx-master:2327754] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 246
# /home/zadoki/miniconda3/envs/gromacs_plumed/lib/python3.9/site-packages/gromacs/setup.py:1116: AutoCorrectionWarning: Size of __main__ is only 3.4% of __environment__ so we use 'System' for T-coupling and ref_t = 300 K and tau_t = 0.1 1/ps (can be changed in mdp_parameters).
#
#   warnings.warn(wmsg, category=AutoCorrectionWarning)
# /home/zadoki/miniconda3/envs/gromacs_plumed/lib/python3.9/site-packages/gromacs/setup.py:781: UsageWarning: Unprocessed mdp option are interpreted as options for grompp:
# {'pp': 'processed.top', 'r': '/rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/MD_POSRES/md.tpr', 'maxwarn': 10}
#   warnings.warn(wmsg, category=UsageWarning)
#                :-) GROMACS - gmx grompp, 2020.6-plumed-2.8.0 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx grompp, version 2020.6-plumed-2.8.0
# Executable:   /home/zadoki/miniconda3/envs/bpti/bin/gmx_mpi
# Data prefix:  /home/zadoki/miniconda3/envs/bpti
# Working dir:  /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/MD
# Command line:
#   gmx_mpi grompp -f md.mdp -p /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/top/system.top -c /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/em/em.pdb -n /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/MD/md.ndx -o md.tpr -pp processed.top -r /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/MD_POSRES/md.tpr -maxwarn 10
#
# Ignoring obsolete mdp entry 'andersen_seed'
# Ignoring obsolete mdp entry 'optimize_fft'
# Ignoring obsolete mdp entry 'ns_type'
# Replacing old mdp entry 'nstxtcout' by 'nstxout-compressed'
# Replacing old mdp entry 'xtc-precision' by 'compressed-x-precision'
#
# NOTE 1 [file md.mdp]:
#   With Verlet lists the optimal nstlist is >= 10, with GPUs >= 20. Note
#   that with the Verlet scheme, nstlist has no effect on the accuracy of
#   your simulation.
#
#
# WARNING 1 [file md.mdp]:
#   You are generating velocities so I am assuming you are equilibrating a
#   system. You are using Parrinello-Rahman pressure coupling, but this can
#   be unstable for equilibration. If your system crashes, try equilibrating
#   first with Berendsen pressure coupling. If you are not equilibrating the
#   system, you can probably ignore this warning.
#
# Setting the LD random seed to -153118871
# Generated 20503 of the 20503 non-bonded parameter combinations
# Generating 1-4 interactions: fudge = 1
# Generated 17396 of the 20503 1-4 parameter combinations
# Excluding 3 bonded neighbours molecule type 'Protein_chain_A'
# Excluding 2 bonded neighbours molecule type 'SOL'
# Excluding 1 bonded neighbours molecule type 'NA'
# Velocities were taken from a Maxwell distribution at 300 K
# Number of degrees of freedom in T-Coupling group System is 10287.00
# Estimate for the relative computational load of the PME mesh part: 0.19
#
# There was 1 note
#
# There was 1 warning
#
# GROMACS reminds you: "Disturb the Peace of a John Q Citizen" (Urban Dance Squad)
#
# [dgx-master:2327777] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 237
# turning H bonds into constraints...
# turning H bonds into constraints...
# turning H bonds into constraints...
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 300 K
# Calculated rlist for 1x1 atom pair-list as 1.008 nm, buffer size 0.008 nm
# Set rlist, assuming 4x4 atom pair-list, to 1.000 nm, buffer size 0.000 nm
# Note that mdrun will redetermine rlist based on the actual pair-list setup
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 32x32x32, spacing 0.118 0.118 0.118
# This run will generate roughly 60 Mb of data
# {'struct': '/rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/MD/md.gro',
#  'top': '/rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/top/system.top',
#  'ndx': '/rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/MD/md.ndx',
#  'qscript': ['./local.sh'],
#  'mainselection': '"Protein"',
#  'deffnm': 'md',
#  'r': '/rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/MD_POSRES/md.tpr',
#  'maxwarn': 10,
#  'nstxout': 100,
#  'nstvout': 0,
#  'nstenergy': 100,
#  'nstxtcout': 0,
#  'nsteps': 100000}
# [dgx-master:2327777] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 246

# %% [markdown]
# ##  make reference pdb for plumed - align on protein backbone

# %%
# load traj
u = mda.Universe(fdir / 'MD_POSRES/md.tpr', fdir / 'MD_POSRES/md.trr' )

u.add_TopologyAttr('tempfactors')
u.add_TopologyAttr('occupancy')

# Select protein
p = u.select_atoms('protein')

u.trajectory[-1]

# set attributes for RMSD and reference
bb = p.select_atoms('backbone')


bb.atoms.tempfactors = 1 
bb.atoms.occupancies  =  1 

# change some oxygen names

p.select_atoms('name OT1').atoms.names = 'O'
p.select_atoms('name OT2').atoms.names = 'OXT'
#[atomselect top "name OT1"] set name O
#[atomselect top "name OT2"] set name OXT



# fix zero based resids
p.residues.resids = p.residues.resids -1 

# save pdb

p.write(fdir / 'reference.pdb', bonds = None )
# Out:
# /home/zadoki/miniconda3/envs/gromacs_plumed/lib/python3.9/site-packages/MDAnalysis/coordinates/PDB.py:1153: UserWarning: Found no information for attr: 'altLocs' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /home/zadoki/miniconda3/envs/gromacs_plumed/lib/python3.9/site-packages/MDAnalysis/coordinates/PDB.py:1153: UserWarning: Found no information for attr: 'icodes' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /home/zadoki/miniconda3/envs/gromacs_plumed/lib/python3.9/site-packages/MDAnalysis/coordinates/PDB.py:1153: UserWarning: Found no information for attr: 'record_types' Using default value of 'ATOM'
#   warnings.warn("Found no information for attr: '{}'"
# /home/zadoki/miniconda3/envs/gromacs_plumed/lib/python3.9/site-packages/MDAnalysis/coordinates/PDB.py:1153: UserWarning: Found no information for attr: 'formalcharges' Using default value of '0'
#   warnings.warn("Found no information for attr: '{}'"

# %%
os.chdir(fdir / 'MD')
shutil.copy2(fdir/ 'reference.pdb', 'reference.pdb')
# Out:
# 'reference.pdb'

# %%
# write plumed cv collection file
with open('plumed.dat', 'w') as f:
    print("""
    # vim:ft=plumed
    # calculate  CVs for HLDA 
    MOLINFO STRUCTURE=reference.pdb MOLTYPE=protein
    WHOLEMOLECULES RESIDUES=all MOLTYPE=protein
    rmsd: RMSD REFERENCE=reference.pdb TYPE=OPTIMAL NOPBC
    e2e: DISTANCE ATOMS=@N-0,@O-9 NOPBC
    rg: GYRATION TYPE=RADIUS ATOMS=@back-0,@back-1,@back-2,@back-3,@back-4,@back-5,@back-6,@back-7,@back-8,@back-9 NOPBC

    # dihedrals
    psi0: TORSION ATOMS=@psi-0 NOPBC
    phi1: TORSION ATOMS=@phi-1 NOPBC
    psi1: TORSION ATOMS=@psi-1 NOPBC
    phi2: TORSION ATOMS=@phi-2 NOPBC
    psi2: TORSION ATOMS=@psi-2 NOPBC
    phi3: TORSION ATOMS=@phi-3 NOPBC
    psi3: TORSION ATOMS=@psi-3 NOPBC
    phi4: TORSION ATOMS=@phi-4 NOPBC
    psi4: TORSION ATOMS=@psi-4 NOPBC
    phi5: TORSION ATOMS=@phi-5 NOPBC
    psi5: TORSION ATOMS=@psi-5 NOPBC
    phi6: TORSION ATOMS=@phi-6 NOPBC
    psi6: TORSION ATOMS=@psi-6 NOPBC
    phi7: TORSION ATOMS=@phi-7 NOPBC
    psi7: TORSION ATOMS=@psi-7 NOPBC
    phi8: TORSION ATOMS=@phi-8 NOPBC
    psi8: TORSION ATOMS=@psi-8 NOPBC
    phi9: TORSION ATOMS=@phi-9 NOPBC

    
    PRINT ...
    ARG=rmsd,e2e,rg,psi0,phi1,psi1,phi2,psi2,phi3,psi3,phi4,psi4,phi5,psi5,phi6,psi6,phi7,psi7,phi8,psi8,phi9
    FILE=COLVAR STRIDE=100
    ... PRINT
    """, file = f)

# %%
subprocess.run('gmx_mpi mdrun  -v -deffnm md -cpi -plumed plumed.dat  -c md.pdb -ntomp 8 -nsteps {} '.format(NSTEPS), shell=True )
# Out:
#                 :-) GROMACS - gmx mdrun, 2020.6-plumed-2.8.0 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx mdrun, version 2020.6-plumed-2.8.0
# Executable:   /home/zadoki/miniconda3/envs/bpti/bin/gmx_mpi
# Data prefix:  /home/zadoki/miniconda3/envs/bpti
# Working dir:  /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/MD
# Command line:
#   gmx_mpi mdrun -v -deffnm md -cpi -plumed plumed.dat -c md.pdb -ntomp 8 -nsteps 100000
#
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/home/zadoki/miniconda3/envs/bpti/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/home/zadoki/miniconda3/envs/bpti/lib/libplumedKernel.so" +++
# Compiled SIMD: SSE2, but for this host/run AVX_512 might be better (see log).
# The current CPU can measure timings more accurately than the code in
# gmx mdrun was configured to use. This might affect your simulation
# speed as accurate timings are needed for load-balancing.
# Please consider rebuilding gmx mdrun with the GMX_USE_RDTSCP=ON CMake option.
# Reading file md.tpr, VERSION 2020.6-plumed-2.8.0 (single precision)
#
# Overriding nsteps with value passed on the command line: 100000 steps, 200 ps
# Changing nstlist from 5 to 50, rlist from 1 to 1.106
#
#
# Using 1 MPI process
# Using 8 OpenMP threads
#
#
# NOTE: The number of threads is not equal to the number of (logical) cores
#       and the -pin option is set to auto: will not pin threads to cores.
#       This can lead to significant performance degradation.
#       Consider using -pin on (and -pinoffset in case you run multiple jobs).
# starting mdrun 'Protein in water'
# 100000 steps,    200.0 ps.
# step 99900, remaining wall clock time:     0 s
# Writing final coordinates.
# step 100000, remaining wall clock time:     0 s
#                Core t (s)   Wall t (s)        (%)
#        Time:     2822.087      352.764      800.0
#                  (ns/day)    (hour/ns)
# Performance:       48.985        0.490
#
# GROMACS reminds you: "What's Your Definition Of Dirty ?" (G. Michael)
# CompletedProcess(args='gmx_mpi mdrun  -v -deffnm md -cpi -plumed plumed.dat  -c md.pdb -ntomp 8 -nsteps 100000 ', returncode=0)
# [dgx-master:2329399] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 237
# [dgx-master:2329399] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 246

# %%
data = panedr.edr_to_df(str(fdir / 'MD/md.edr'))

# %%
data.iloc[10:,:].plot(x='Time', y='Temperature')
# Out:
# <Axes: xlabel='Time'>

# %%
data.iloc[10:,:].plot(x='Time', y='Pressure')
# Out:
# <Axes: xlabel='Time'>

# %%
data.iloc[10:,:].plot(x='Time', y='Total Energy')
# Out:
# <Axes: xlabel='Time'>

# %%
data.iloc[10:,:].plot(x='Time', y='Potential')
# Out:
# <Axes: xlabel='Time'>

# %%
data.columns
# Out:
# Index(['Time', 'Bond', 'U-B', 'Proper Dih.', 'Improper Dih.', 'CMAP Dih.',
#        'LJ-14', 'Coulomb-14', 'LJ (SR)', 'Disper. corr.', 'Coulomb (SR)',
#        'Coul. recip.', 'Potential', 'Kinetic En.', 'Total Energy',
#        'Conserved En.', 'Temperature', 'Pres. DC', 'Pressure', 'Constr. rmsd',
#        'Box-X', 'Box-Y', 'Box-Z', 'Volume', 'Density', 'pV', 'Enthalpy',
#        'Vir-XX', 'Vir-XY', 'Vir-XZ', 'Vir-YX', 'Vir-YY', 'Vir-YZ', 'Vir-ZX',
#        'Vir-ZY', 'Vir-ZZ', 'Pres-XX', 'Pres-XY', 'Pres-XZ', 'Pres-YX',
#        'Pres-YY', 'Pres-YZ', 'Pres-ZX', 'Pres-ZY', 'Pres-ZZ', '#Surf*SurfTen',
#        'Box-Vel-XX', 'Box-Vel-YY', 'Box-Vel-ZZ', 'T-System', 'Lamb-System'],
#       dtype='object')

# %%
# bootstrapping averages for convergence
dd = data["Potential"].to_numpy()
length = dd.shape[0]
num_points = 1000
num_straps = 10000
bootstraps = np.zeros(num_straps)

for i in range(num_straps) : 
    av = 0
    av2 = 0 
    for j in range(num_points) : av = av + dd[np.random.randint(0,length)]
    
    bootstraps[i] = (av / num_points)

# %%
bootstraps.mean(), bootstraps.var()
# Out:
# (-67876.82261711718, 164.67346084420672)

# %% [markdown]
# ## Unfold protein

# %%
ufdir = base / 'data/interim/YYDPENGTWY/state_unfolded'
os.makedirs(str(ufdir), exist_ok=True)
os.chdir(ufdir)

# %%
os.getcwd()
# Out:
# '/rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_unfolded'

# %%
# copy some files
MD(r=str(fdir / 'MD_POSRES/md.tpr') , maxwarn=10, nstxout=NSTXOUT, nstvout=0, nstenergy=NSTENERGY, nstxtcout = 0, nsteps= NSTEPS, **f3)
# Out:
#               :-) GROMACS - gmx make_ndx, 2020.6-plumed-2.8.0 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx make_ndx, version 2020.6-plumed-2.8.0
# Executable:   /home/zadoki/miniconda3/envs/bpti/bin/gmx_mpi
# Data prefix:  /home/zadoki/miniconda3/envs/bpti
# Working dir:  /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_unfolded/MD
# Command line:
#   gmx_mpi make_ndx -f /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/em/em.pdb -o md.ndx
#
#
# Reading structure file
#
# GROMACS reminds you: "As we all know, blinking lights means science." (Joss Whedon)
#
# [dgx-master:2647741] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 237
# [dgx-master:2647741] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 246
#               :-) GROMACS - gmx make_ndx, 2020.6-plumed-2.8.0 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx make_ndx, version 2020.6-plumed-2.8.0
# Executable:   /home/zadoki/miniconda3/envs/bpti/bin/gmx_mpi
# Data prefix:  /home/zadoki/miniconda3/envs/bpti
# Working dir:  /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_unfolded/MD
# Command line:
#   gmx_mpi make_ndx -f /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/em/em.pdb -n md.ndx -o md.ndx
#
#
# Reading structure file
#
# Back Off! I just backed up md.ndx to ./#md.ndx.1#
#
# GROMACS reminds you: "Check Your Input" (D. Van Der Spoel)
#
# [dgx-master:2647803] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 237
# [dgx-master:2647803] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 237
# [dgx-master:2647803] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 246
# /home/zadoki/miniconda3/envs/gromacs_plumed/lib/python3.9/site-packages/gromacs/setup.py:1116: AutoCorrectionWarning: Size of __main__ is only 3.4% of __environment__ so we use 'System' for T-coupling and ref_t = 300 K and tau_t = 0.1 1/ps (can be changed in mdp_parameters).
#
#   warnings.warn(wmsg, category=AutoCorrectionWarning)
# /home/zadoki/miniconda3/envs/gromacs_plumed/lib/python3.9/site-packages/gromacs/setup.py:781: UsageWarning: Unprocessed mdp option are interpreted as options for grompp:
# {'pp': 'processed.top', 'r': '/rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/MD_POSRES/md.tpr', 'maxwarn': 10}
#   warnings.warn(wmsg, category=UsageWarning)
#                :-) GROMACS - gmx grompp, 2020.6-plumed-2.8.0 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx grompp, version 2020.6-plumed-2.8.0
# Executable:   /home/zadoki/miniconda3/envs/bpti/bin/gmx_mpi
# Data prefix:  /home/zadoki/miniconda3/envs/bpti
# Working dir:  /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_unfolded/MD
# Command line:
#   gmx_mpi grompp -f md.mdp -p /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/top/system.top -c /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/em/em.pdb -n /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_unfolded/MD/md.ndx -o md.tpr -pp processed.top -r /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/MD_POSRES/md.tpr -maxwarn 10
#
# Ignoring obsolete mdp entry 'andersen_seed'
# Ignoring obsolete mdp entry 'optimize_fft'
# Ignoring obsolete mdp entry 'ns_type'
# Replacing old mdp entry 'nstxtcout' by 'nstxout-compressed'
# Replacing old mdp entry 'xtc-precision' by 'compressed-x-precision'
#
# NOTE 1 [file md.mdp]:
#   With Verlet lists the optimal nstlist is >= 10, with GPUs >= 20. Note
#   that with the Verlet scheme, nstlist has no effect on the accuracy of
#   your simulation.
#
#
# WARNING 1 [file md.mdp]:
#   You are generating velocities so I am assuming you are equilibrating a
#   system. You are using Parrinello-Rahman pressure coupling, but this can
#   be unstable for equilibration. If your system crashes, try equilibrating
#   first with Berendsen pressure coupling. If you are not equilibrating the
#   system, you can probably ignore this warning.
#
# Setting the LD random seed to -149569729
# Generated 20503 of the 20503 non-bonded parameter combinations
# Generating 1-4 interactions: fudge = 1
# Generated 17396 of the 20503 1-4 parameter combinations
# Excluding 3 bonded neighbours molecule type 'Protein_chain_A'
# Excluding 2 bonded neighbours molecule type 'SOL'
# Excluding 1 bonded neighbours molecule type 'NA'
# Velocities were taken from a Maxwell distribution at 300 K
# Number of degrees of freedom in T-Coupling group System is 10287.00
# Estimate for the relative computational load of the PME mesh part: 0.19
#
# There was 1 note
#
# There was 1 warning
#
# GROMACS reminds you: "Check Your Input" (D. Van Der Spoel)
# turning H bonds into constraints...
# turning H bonds into constraints...
# turning H bonds into constraints...
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 300 K
# Calculated rlist for 1x1 atom pair-list as 1.008 nm, buffer size 0.008 nm
# Set rlist, assuming 4x4 atom pair-list, to 1.000 nm, buffer size 0.000 nm
# Note that mdrun will redetermine rlist based on the actual pair-list setup
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 32x32x32, spacing 0.118 0.118 0.118
# This run will generate roughly 60 Mb of data
# [dgx-master:2647875] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 237
# [dgx-master:2647875] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 237
# [dgx-master:2647875] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 237
# [dgx-master:2647875] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 246
# {'struct': '/rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_unfolded/MD/md.gro',
#  'top': '/rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/top/system.top',
#  'ndx': '/rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_unfolded/MD/md.ndx',
#  'qscript': ['./local.sh'],
#  'mainselection': '"Protein"',
#  'deffnm': 'md',
#  'r': '/rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_folded/MD_POSRES/md.tpr',
#  'maxwarn': 10,
#  'nstxout': 100,
#  'nstvout': 0,
#  'nstenergy': 100,
#  'nstxtcout': 0,
#  'nsteps': 100000}

# %% [markdown]
# # write plumed strech file

# %%
shutil.copy2(fdir/ 'reference.pdb', ufdir/ 'reference.pdb')
# Out:
# PosixPath('/rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_unfolded/reference.pdb')

# %%
# use plumed to strech protein
with open(ufdir / "MD/plumed_strech.dat","w") as f:
    print("""# vim:ft=plumed
# add a restraint to strech the protein into unfolded state
MOLINFO STRUCTURE={}.pdb MOLTYPE=protein
WHOLEMOLECULES RESIDUES=all MOLTYPE=protein
rmsd: RMSD REFERENCE={}.pdb TYPE=OPTIMAL NOPBC
e2e: DISTANCE ATOMS=@N-0,@C-9 NOPBC
res: RESTRAINT ARG=e2e KAPPA=100 AT=2.5
PRINT ARG=e2e,rmsd,res.bias FILE=COLVAR_STRECH STRIDE=10
     """.format('reference','reference'),file=f)

# %%
shutil.copy2(fdir/ 'reference.pdb', ufdir/ 'MD/reference.pdb')
shutil.copy2(fdir/ 'MD/plumed.dat', ufdir/ 'MD/plumed.dat')
# Out:
# PosixPath('/rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_unfolded/MD/plumed.dat')

# %%
os.chdir(ufdir/'MD')

# %%
clean()
# Out:
# CompletedProcess(args='rm -f \\#*; rm -fr bck.*', returncode=0)

# %%
# Strech protein 

subprocess.run('gmx_mpi mdrun  -v -deffnm md -plumed plumed_strech.dat -nsteps 100000 -c md.pdb -ntomp 8 ', shell=True )
# Out:
#                 :-) GROMACS - gmx mdrun, 2020.6-plumed-2.8.0 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx mdrun, version 2020.6-plumed-2.8.0
# Executable:   /home/zadoki/miniconda3/envs/bpti/bin/gmx_mpi
# Data prefix:  /home/zadoki/miniconda3/envs/bpti
# Working dir:  /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_unfolded/MD
# Command line:
#   gmx_mpi mdrun -v -deffnm md -plumed plumed_strech.dat -nsteps 100000 -c md.pdb -ntomp 8
#
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/home/zadoki/miniconda3/envs/bpti/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/home/zadoki/miniconda3/envs/bpti/lib/libplumedKernel.so" +++
# Compiled SIMD: SSE2, but for this host/run AVX_512 might be better (see log).
# The current CPU can measure timings more accurately than the code in
# gmx mdrun was configured to use. This might affect your simulation
# speed as accurate timings are needed for load-balancing.
# Please consider rebuilding gmx mdrun with the GMX_USE_RDTSCP=ON CMake option.
# Reading file md.tpr, VERSION 2020.6-plumed-2.8.0 (single precision)
#
# Overriding nsteps with value passed on the command line: 100000 steps, 200 ps
# Changing nstlist from 5 to 50, rlist from 1 to 1.106
#
#
# Using 1 MPI process
# Using 8 OpenMP threads
#
#
# NOTE: The number of threads is not equal to the number of (logical) cores
#       and the -pin option is set to auto: will not pin threads to cores.
#       This can lead to significant performance degradation.
#       Consider using -pin on (and -pinoffset in case you run multiple jobs).
# starting mdrun 'Protein in water'
# 100000 steps,    200.0 ps.
# step 99900, remaining wall clock time:     0 s
# Writing final coordinates.
# step 100000, remaining wall clock time:     0 s
#                Core t (s)   Wall t (s)        (%)
#        Time:     2809.499      351.190      800.0
#                  (ns/day)    (hour/ns)
# Performance:       49.205        0.488
#
# GROMACS reminds you: "If you don't know what you're doing, use a (M)BAR-based method" (Erik Lindahl)
# CompletedProcess(args='gmx_mpi mdrun  -v -deffnm md -plumed plumed_strech.dat -nsteps 100000 -c md.pdb -ntomp 8 ', returncode=0)
# [dgx-master:2651680] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 237
# [dgx-master:2651680] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 237
# [dgx-master:2651680] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 246

# %%
data = plumed.read_as_pandas('COLVAR_STRECH')

data.plot('time','e2e', label='e2e')
data.plot('time','rmsd', label='rmsd')
data.plot('time','res.bias', label='bias')
# Out:
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/home/zadoki/miniconda3/envs/gromacs_plumed/lib/libplumedKernel.so" +++
# <Axes: xlabel='time'>

# %%
# simulate and collect CVs


subprocess.run('gmx_mpi mdrun  -v -deffnm md -cpi  -plumed plumed.dat -nsteps {} -c md.pdb -ntomp 8'.format(NSTEPS), shell=True )
# Out:
#                 :-) GROMACS - gmx mdrun, 2020.6-plumed-2.8.0 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx mdrun, version 2020.6-plumed-2.8.0
# Executable:   /home/zadoki/miniconda3/envs/bpti/bin/gmx_mpi
# Data prefix:  /home/zadoki/miniconda3/envs/bpti
# Working dir:  /rg/mendels_prj/zadoki/chignolin_test/data/interim/YYDPENGTWY/state_unfolded/MD
# Command line:
#   gmx_mpi mdrun -v -deffnm md -cpi -plumed plumed.dat -nsteps 100000 -c md.pdb -ntomp 8
#
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/home/zadoki/miniconda3/envs/bpti/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/home/zadoki/miniconda3/envs/bpti/lib/libplumedKernel.so" +++
# Compiled SIMD: SSE2, but for this host/run AVX_512 might be better (see log).
# The current CPU can measure timings more accurately than the code in
# gmx mdrun was configured to use. This might affect your simulation
# speed as accurate timings are needed for load-balancing.
# Please consider rebuilding gmx mdrun with the GMX_USE_RDTSCP=ON CMake option.
# Reading file md.tpr, VERSION 2020.6-plumed-2.8.0 (single precision)
# Overriding nsteps with value passed on the command line: 100000 steps, 200 ps
# Changing nstlist from 5 to 50, rlist from 1 to 1.109
#
#
# Using 1 MPI process
# Using 8 OpenMP threads
#
#
# NOTE: The number of threads is not equal to the number of (logical) cores
#       and the -pin option is set to auto: will not pin threads to cores.
#       This can lead to significant performance degradation.
#       Consider using -pin on (and -pinoffset in case you run multiple jobs).
# starting mdrun 'Protein in water'
# 200000 steps,    400.0 ps (continuing from step 100000,    200.0 ps).
# step 199900, remaining wall clock time:     0 s
# Writing final coordinates.
#
# Back Off! I just backed up md.pdb to ./#md.pdb.1#
# step 200000, remaining wall clock time:     0 s
#                Core t (s)   Wall t (s)        (%)
#        Time:     2722.402      340.303      800.0
#                  (ns/day)    (hour/ns)
# Performance:       50.779        0.473
#
# GROMACS reminds you: "As always in life, people want a simple answer... and it's always wrong." (Marie Daly)
# CompletedProcess(args='gmx_mpi mdrun  -v -deffnm md -cpi  -plumed plumed.dat -nsteps 100000 -c md.pdb -ntomp 8', returncode=0)
# [dgx-master:2673193] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 237
# [dgx-master:2673193] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 237
# [dgx-master:2673193] PMIX ERROR: NO-PERMISSIONS in file dstore_base.c at line 246

# %% [markdown]
# ## visualize with nglview

# %%
os.chdir(ufdir/ 'MD')

u = mda.Universe('md.tpr', 'md.trr')

# %%
u.trajectory.n_frames

u.universe.residues[1000]

prot = u.select_atoms("(protein and not type H) or (resname SOL within 2)")

prot
# Out:
# <AtomGroup with 5080 atoms>

# %%
view = nglview.show_mdanalysis(prot)
view
# Out:
# NGLWidget(max_frame=2000)

# %% [markdown]
# # Calculate HLDA CV

# %% [markdown]
# ## Let's see the states first

# %%
from harmonic_discriminant_analysis import HarmonicLinearDiscriminantAnalysis
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
import seaborn as sns

# %%
data = pd.concat([
    (plumed.read_as_pandas(str(fdir / 'MD/COLVAR'))).assign(state = 'folded'),
    (plumed.read_as_pandas(str(ufdir / 'MD/COLVAR'))).assign(state = 'unfolded')]).reset_index(drop=True)
# Out:
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/home/zadoki/miniconda3/envs/gromacs_plumed/lib/libplumedKernel.so" +++
# +++ Loading the PLUMED kernel runtime +++
# +++ PLUMED_KERNEL="/home/zadoki/miniconda3/envs/gromacs_plumed/lib/libplumedKernel.so" +++

# %%
data[data.state == 'folded'].plot('time','rmsd', label = 'folded')
data[data.state == 'unfolded'].plot('time','rmsd', label = 'unfolded')
# Out:
# <Axes: xlabel='time'>

# %%
data[data.state == 'folded'].plot('time','e2e', label = 'folded')
data[data.state == 'unfolded'].plot('time','e2e', label = 'unfolded')
# Out:
# <Axes: xlabel='time'>

# %%
data.plot('e2e','rmsd', kind='scatter')
# Out:
# <Axes: xlabel='e2e', ylabel='rmsd'>

# %%
X = data.iloc[:,data.columns.str.contains('^p')].copy(deep=True)
y = data.state

# apply unwrap 
X = X.apply(np.unwrap,)

# %%
hlda = HarmonicLinearDiscriminantAnalysis()

# %%
hlda.fit(X,y)
# Out:
# HarmonicLinearDiscriminantAnalysis()

# %% [markdown]
# ## Plot State separation

# %%
plt.hist(hlda.transform(X)[y == 'folded'],  label = 'folded' )
plt.hist(hlda.transform(X)[y == 'unfolded'], label = 'unfolded' )
plt.legend()
plt.show()

# %%
hlda_evects = (hlda.scalings_)[:,0]

# %% [markdown]
# ## Plot HLDA coefficients

# %%
fig = plt.figure()
sortx = np.argsort(np.abs(hlda_evects.flatten()),)[::-1]
plt.bar(X.columns[sortx],hlda_evects.flatten()[sortx],align='center', width=0.7)
plt.xticks(rotation=90,fontsize=6)
plt.xlabel('CV')
plt.ylabel('Coefficient Size')
plt.show()

# %%
X.shape
# Out:
# (2002, 19)
